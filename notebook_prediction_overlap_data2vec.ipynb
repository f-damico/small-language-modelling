# %% [markdown]
# # Imports and functions

# %%
import sys
import matplotlib.pyplot as plt 

sys.path.insert(0, "./data2vec")

from data2vec.plot_data2vec_predictive_overlaps import (
    plot_data2vec_predictive_same_layer_overlap_vs_time,
)

# %% [markdown]
# # Runs

# %%
fig, ax, info = plot_data2vec_predictive_same_layer_overlap_vs_time(
    results_dir="./collected_results",
    output_name="overlap_predictive_DATA2VEC_state_v3",
    position="mean",
    alpha_mode="position_mean",
    time_key="steps",
    xscale="log",
    use_saved_best=False
)

plt.show()

# %%
fig, ax, info = plot_data2vec_predictive_same_layer_overlap_vs_time(
    results_dir="./collected_results",
    output_name="overlap_predictive_DATA2VEC_stream_v3",
    position="mean",
    alpha_mode="position_mean",
    time_key="steps",
    xscale="log",
)

plt.show()
