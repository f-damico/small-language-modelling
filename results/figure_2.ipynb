# %%
import sys
sys.path.append("../")
from pathlib import Path

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import torch

# %%
p_list_cm = [2**i for i in range(16, 29)] + [529_203_200]
base = matplotlib.colormaps["viridis"]
cmap  = matplotlib.colors.LinearSegmentedColormap.from_list(
    "viridis_trunc", base(np.linspace(0.05, 0.9, 256))
)
norm = matplotlib.colors.LogNorm(vmin=p_list_cm[0], vmax=p_list_cm[-1])

# %% [markdown]
# # Panels of figure 2

# %%
A = 3.55
gamma = 0.325

# %% [markdown]
# ## 1st: T=512, GPT2 with APE

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})

fig = plt.figure(figsize=(1*2.2, 1*2.2), dpi=120)
L, B, W, H = 0.18, 0.18, 0.72, 0.72 
ax  = fig.add_axes([L, B, W, H])

T = 512
depth = 12

results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T}_d{depth}.pt")
p_list = results['data']
print(p_list)
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]

for i, p in enumerate(p_list):
    ax.plot([t+1 for t in range(T)], ngrams_list[i], color=cmap(norm(p+1)), label=fr'$P={p}$')

ax.plot([t+1 for t in range(32)], [A*(t+1)**(-gamma) for t in range(32)],'k--')

# ax.legend(fontsize=8, handlelength=1)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylabel(r'$\mathcal{L}_{n}$', fontsize=10)
ax.set_xlabel(r'$n$', fontsize=10)

ticks  = [ 1, 2, 3, 4, 6]
labels = [ "1", "2", "3", "4", "6"]
ax.set_yticks(ticks)
ax.set_yticklabels(labels)
ax.yaxis.set_minor_locator(mticker.NullLocator())

ax.set_ylim(0.8, 6.)
# Out:
# [1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 529203200]
# (0.8, 6.0)

# %%
fig.savefig(f'tinystories/conditional-entropy_tinystories.BPE8192_T{T}_APE_Left.pdf', bbox_inches="tight")

# %% [markdown]
# ## 2nd: T=512, GPT2 with RoPE

# %%
fig = plt.figure(constrained_layout=True, figsize=(1*2.1, 1*2.2), dpi=120)

fig = plt.figure(figsize=(1*2.2, 1*2.2), dpi=120)  # can be same for all
L, B, W, H = 0.18, 0.18, 0.72, 0.72 
ax  = fig.add_axes([L, B, W, H])                # <-- plot box is fixed

T = 512
depth = 12

results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T}_d{depth}_rope.pt")
p_list = results['data']
print(p_list)
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]

for i, p in enumerate(p_list):
    ax.plot([t+1 for t in range(T)], ngrams_list[i], color=cmap(norm(p+1)), label=fr'$P={p}$')

ax.plot([t+1 for t in range(32)], [A*(t+1)**(-gamma) for t in range(32)],'k--')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$n$', fontsize=10)

ax.set_ylim(0.8, 6.)

ax.yaxis.set_minor_locator(mticker.NullLocator())
ax.yaxis.set_major_locator(mticker.NullLocator())
# Out:
# [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456, 529203200]

# %%
fig.savefig(f'tinystories/conditional-entropy_tinystories.BPE8192_T{T}_RoPE_Middle.pdf', bbox_inches="tight")

# %% [markdown]
# ## 3nd: T=511, Llama

# %%
fig = plt.figure(constrained_layout=True, figsize=(1*2.1, 1*2.2), dpi=120)

fig = plt.figure(figsize=(1*2.2, 1*2.2), dpi=120)  # can be same for all
L, B, W, H = 0.18, 0.18, 0.72, 0.72 
ax  = fig.add_axes([L, B, W, H])                # <-- plot box is fixed

T = 511
depth = 12

results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T}_llama.pt")
p_list = results['data']
print(p_list)
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]

for i, p in enumerate(p_list):
    ax.plot([t+1 for t in range(T)], ngrams_list[i], color=cmap(norm(p+1)), label=fr'$P={p}$')

ax.plot([t+1 for t in range(32)], [A*(t+1)**(-gamma) for t in range(32)],'k--')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$n$', fontsize=10)

ax.set_ylim(0.8, 6.)

ax.yaxis.set_minor_locator(mticker.NullLocator())
ax.yaxis.set_major_locator(mticker.NullLocator())


CB_W  = 0.04
CB_PAD = 0.02
want_cbar = True
sm = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array(np.array(p_list_cm))
if want_cbar:
    cax = fig.add_axes([L + W + CB_PAD, B, CB_W, H])
    cbar = fig.colorbar(sm, cax=cax)

cbar.ax.set_xlabel(r'$P$', labelpad=4)
cbar.ax.yaxis.set_label_position('right')
cbar.ax.yaxis.set_ticks_position('right')

ticks = [2**16, 2**20, 2**24, 2**28]
cbar.set_ticks(ticks)
exps = np.log2(ticks).astype(int)
cbar.set_ticklabels([rf"$2^{{{e}}}$" for e in exps])
# Out:
# [1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456]

# %%
plt.savefig(f"tinystories/conditional-entropy_tinystories.BPE8192_T512_Llama_Right.pdf", bbox_inches="tight")

# %% [markdown]
# ## Final: Comparison at convergence + mamba and n-gram

# %%
fig = plt.figure(figsize=(1*2.2, 1*2.2), dpi=120)
L, B, W, H = 0.18, 0.18, 0.72, 0.72 
ax  = fig.add_axes([L, B, W, H])

T = 512
depth = 12

# base = matplotlib.colormaps["plasma"]
# cmap  = matplotlib.colors.LinearSegmentedColormap.from_list(
#     "plasma_trunc", base(np.linspace(0.05, 0.9, 256))
# )
# norm = matplotlib.colors.LogNorm(vmin=p_list[0], vmax=p_list[-1])

colors = ["#8C1D18", "#1F4E79", "#6A8E3F", "#D89C1D", "#6B4C9A"]

# GPT2 APE
results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T}_d{depth}.pt")
p_list = results['data']
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]
ax.plot([t+1 for t in range(T)], ngrams_list[-1], color=colors[0], label=fr'GPT-2 APE')

# GPT2 RoPE
results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T}_d{depth}_rope.pt")
p_list = results['data']
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]
print(len(results["data"]), len(results["ngrams"]), results["ngrams"][0].shape, results["ngrams"][0].dtype)
ax.plot([t+1 for t in range(T)], ngrams_list[-1], color=colors[1], label=fr'GPT-2 RoPE')

# LLaMA
results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T-1}_llama.pt")
p_list = results['data']
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]
print(len(results["data"]), len(results["ngrams"]), results["ngrams"][0].shape, results["ngrams"][0].dtype)
ax.plot([t+1 for t in range(T-1)], ngrams_list[-1], color=colors[2], label=fr'LLaMA')

# mamba
T = 128
results = torch.load(f"tinystories/learning-curves/ngrams_tinystories.BPE8192_T{T}_d{depth}_mamba.pt")
p_list = results['data']
ngrams_list = [n.mean(dim=0) for n in results['ngrams']]
ax.plot([t+1 for t in range(T)], ngrams_list[-1], color=colors[3], label=fr'Mamba')

# N-gram (infinigram)
T = 128
results = np.load(f"tinystories/learning-curves/suffixarray_p28_curve.npy")
ax.plot([t+1 for t in range(len(results))], results, color=colors[4], label=fr'N-gram')

# Gamma fit
ax.plot([t+1 for t in range(32)], [A*(t+1)**(-gamma) for t in range(32)],'k--', label=rf"$n^{{-\gamma}}$, $\gamma=${gamma}")

ax.legend(fontsize=7, handlelength=1)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$n$', fontsize=10)

ax.yaxis.set_minor_locator(mticker.NullLocator())
ax.yaxis.set_major_locator(mticker.NullLocator())

ax.set_ylim(0.8, 6.)
# Out:
# 8 8 torch.Size([4, 512]) torch.float32
# 9 9 torch.Size([1, 511]) torch.float32
# (0.8, 6.0)

# %%
fig.savefig(f'tinystories/conditional-entropy_tinystories.BPE8192_CompArch.pdf', bbox_inches="tight")
