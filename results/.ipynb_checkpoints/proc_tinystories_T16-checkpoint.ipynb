# %%
import os
import sys
import time
import copy
sys.path.append('../SLM/')

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import json
import math
import random

import fnmatch
import re
from itertools import product, groupby

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from tokenizers import Tokenizer

import models, init, train, measures
import importlib
# Reload the modules
importlib.reload( models)

device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(device)

def collect(path, prefix, *keys):

    all_entries = os.listdir(path)
    matching_entries = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
#                 params = re.findall(r'_P(\d+)', ending)
#                 assert params, f'{entry}: trainsize p not found!'
                array = re.findall(r'_(\d+)', ending)
                matching_entries.append({
                    'ending': ending,
#                     'P': int(params[0]),
                    'seed': int(array[0])
                })
#     matching_entries.sort(key=lambda x: [x.get('P'), x.get('exp')])
    return matching_entries


def find_all(path, prefix, what, *keys):
    
    all_entries = os.listdir(path)
    params = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
                param = re.findall(what+r'(\d+)', ending)
                param = int(param[0])
                if param not in params:
                    params.append(param)
    params.sort()
    return params


def find_lowest(path, prefix, what, *keys):
    
    all_entries = os.listdir(path)
    params = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
                param = re.findall(what+r'(\d+)', ending)
                param = int(param[0])
                if param not in params:
                    params.append(param)
    params.sort()
    return params[0]


def get_loss(path, prefix):

    loss_list = []

    p_list = find_all(path, prefix, 'P')
    print('training set sizes: ', p_list)

    for  p in p_list:

        bs = find_lowest(path, prefix, 'bs', f'P{p}_')
        print(f'P={p}, batch size={bs}')
        collection = collect( path, prefix, f'P{p}_', f'bs{bs}_')
        loss = []

        for entry in collection:
            try:
                results = torch.load(path+prefix+entry['ending'])
                print(p, results['best']['loss'])
                loss.append(results['best']['loss'])

            except:
                print(path+prefix+entry['ending']+f' not found.')


        print(f'{len(loss)} exps. , mean loss {torch.tensor(loss).mean()}')
        loss_list.append(torch.tensor(loss))
    return loss_list


fig, ax = plt.subplots(1, 2, figsize=(20,5.0))
# Out:
# cuda

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 1, figsize=(1*5.7, 1*3.6), dpi=120)
custom_lines = []
custom_labels = []


vocab_size = 8192
split = 'train'

T = 16
path = f'tinystories/trained/T{T}/'

bs = 128
depth = 12
de = 768
nh = 12
lr = '3e-4'

n=16

for i,P in enumerate([2**17, 2**18, 2**19, 2**20, 2**21, 2**22, 2**23, 2**24, 2**25, 2**26, 2**27, 2**28, 529203200]): 

#     if P <= 2**21:
#         dt = 2048
#     else:
#         dt = (P//(T*bs))*8
    prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'#_dt{dt}'
    collection = collect( path, prefix)
    for entry in collection:

        results = torch.load(path+prefix+entry['ending'])
        dynamics = results['dynamics']
        ax.plot([d['t'] for d in dynamics], [d['val_loss'] for d in dynamics], f'C{i}', label=f'P={P}, T={T}')
        print(T, entry['seed'], min([d['val_loss'] for d in dynamics]), results['best']['step'], dynamics[-1]['t'])
    ax.plot([P//(T*bs),P//(T*bs)], [1e0,1e1], f'C{i}', linestyle='dashed')
    custom_lines.append(Line2D([0], [0], color=f'C{i}'))
    custom_labels.append(fr'$P={P}$, $T={T}$')

ax.plot([1e0,1e3],[math.log(8192),math.log(8192)], 'k--')
custom_lines.append(Line2D([0], [0], color='k', linestyle='dashed'))
custom_labels.append(fr'trivial entropy')

marginal = np.load("../SLM/datasets/tinystories/"+f"tinystories.BPE{vocab_size}.{split}_marginal.npy")
marginal = torch.from_numpy(marginal)
marg_ent = torch.masked_select(marginal, (marginal>0))
print(marg_ent.size())
marg_ent = -(marg_ent*marg_ent.log()).sum()
print(marg_ent)
ax.plot([1e0,1e3],[marg_ent.cpu(),marg_ent.cpu()], 'r--')
custom_lines.append(Line2D([0], [0], color='r', linestyle='dashed'))
custom_labels.append(fr'marginal entropy')


ax.legend(custom_lines, custom_labels, fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax.set_xscale('log')
# ax.set_ylim(1.,5.)
ax.set_yscale('log')

ax.set_ylabel(fr'val loss', fontsize=11)
ax.set_xlabel(fr'training step (batch size $={bs}$)', fontsize=11)

fig.tight_layout()
# Out:
# 16 7994586 3.778869517147541 511 1024
# 16 5510013 3.807228577323258 511 1024
# 16 9142050 3.787682288326323 511 1024
# 16 1588153 3.8132656533271074 511 1024
# 16 14372969 3.532539326697588 723 2048
# 16 15877567 3.49905947688967 723 2048
# 16 15255450 3.505987113341689 723 2048
# 16 4761722 3.4991993606090546 723 2048
# 16 7832973 3.2452863417565823 1023 4096
# 16 1056652 3.260515664704144 1023 4096
# 16 13754768 3.271410310640931 1023 4096
# 16 526647 3.273847933858633 1447 4096
# 16 9284199 3.0297282906249166 2047 8192
# 16 14623181 3.0377580178901553 2047 8192
# 16 16392291 3.0467962231487036 2047 8192
# 16 13301555 3.012598969042301 2047 8192
# 16 585543 2.836450058966875 2895 16384
# 16 15518975 2.8710661260411143 2895 16384
# 16 10410693 2.8435717979446054 2895 16384
# 16 8532189 2.8365645008161664 2895 16384
# 16 9352186 2.6963243326172233 5119 32768
# 16 7382734 2.67446222435683 6143 32768
# 16 13462132 2.699439018033445 6143 32768
# 16 4445264 2.6785543989390135 6143 32768
# 16 4666184 2.536393572576344 11263 65536
# 16 10286325 2.5314732613041997 12287 65536
# 16 5960573 2.5167177310213447 12287 65536
# 16 12972656 2.5098130479454994 10239 65536
# 16 6952554 2.38558841124177 24575 131072
# 16 14271488 2.368766198400408 24575 131072
# 16 5375728 2.381260048598051 23551 131072
# 16 2758759 2.3759256275370717 24575 131072
# 16 6193575 2.262581813149154 50175 262144
# 16 14960928 2.276901461649686 49151 262144
# 16 9257794 2.255261320155114 50175 262144
# 16 14178665 2.267365998122841 51199 262144
# 16 2004399 2.1693000202067196 117759 524288
# 16 8678833 2.1714369179680943 113663 524288
# 16 14532068 2.1778614185750484 115711 524288
# 16 4614978 2.1841516122221947 109567 524288
# 16 5671228 2.1021558474749327 299007 1048576
# 16 16085247 2.0970679791644216 254975 1048576
# 16 5652280 2.11006743600592 267263 1048576
# 16 11017013 2.1042757048271596 266239 1048576
# 16 6743143 2.019651101436466 766975 2097152
# 16 2758131 2.048458813689649 716799 2097152
# 16 7475649 2.0395817020908 793599 2097152
# 16 11360012 2.0294436467811465 843775 2097152
# 16 14150592 1.9753108695149422 1835007 2965504
# 16 10995060 1.9836685415357351 1788927 2965504
# 16 7012351 1.9836325626820326 1807359 2965504
# 16 4357182 1.9905784302391112 1811455 2965504
# torch.Size([8130])
# tensor(5.7761)

# %%
fig.savefig('tinystories/'+f'dynamics-vs-num-data_T{T}_d12_demb768_nh12_bs{bs}_lr3e-4.pdf')

# %%
P = 529203200
dt = (P//(T*bs))*8
prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8_dt{dt}'
collection = collect( path, prefix)
for entry in collection:

    results = torch.load(path+prefix+entry['ending'])
    trained = results['best']['model']
    print(results.keys())
    print(results['best'].keys())
# Out:
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])

# %% [markdown]
# # LEARNING CURVE (loss vs num. data)

# %%
vocab_size = 8192
split='train'
T = 16
path = f'tinystories/trained/T{T}/'

error_list = get_loss(path, f'tinystories.BPE8192_T{T}')
p_list = find_all(path, f'tinystories.BPE8192_T{T}', 'P')
# Out:
# training set sizes:  [32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 529203200]
# P=32768, batch size=128
# 32768 4.467498196288943
# 32768 4.484566682949662
# 32768 4.478424308821559
# 32768 4.5003348384052515
# 4 exps. , mean loss 4.482706069946289
# P=65536, batch size=128
# 65536 4.1203395910561085
# 65536 4.121044358238578
# 65536 4.140920157544315
# 65536 4.111359579488635
# 4 exps. , mean loss 4.123415946960449
# P=131072, batch size=128
# 131072 3.778869517147541
# 131072 3.807228577323258
# 131072 3.787682288326323
# 131072 3.8132656533271074
# 4 exps. , mean loss 3.7967615127563477
# P=262144, batch size=128
# 262144 3.532539326697588
# 262144 3.49905947688967
# 262144 3.505987113341689
# 262144 3.4991993606090546
# 4 exps. , mean loss 3.5091962814331055
# P=524288, batch size=128
# 524288 3.2452863417565823
# 524288 3.260515664704144
# 524288 3.271410310640931
# 524288 3.273847933858633
# 4 exps. , mean loss 3.2627649307250977
# P=1048576, batch size=128
# 1048576 3.0297282906249166
# 1048576 3.0377580178901553
# 1048576 3.0467962231487036
# 1048576 3.012598969042301
# 4 exps. , mean loss 3.0317203998565674
# P=2097152, batch size=128
# 2097152 2.836450058966875
# 2097152 2.8710661260411143
# 2097152 2.8435717979446054
# 2097152 2.8365645008161664
# 4 exps. , mean loss 2.8469133377075195
# P=4194304, batch size=128
# 4194304 2.6913719521835446
# 4194304 2.67446222435683
# 4194304 2.699439018033445
# 4194304 2.6785543989390135
# 4 exps. , mean loss 2.6859569549560547
# P=8388608, batch size=128
# 8388608 2.536393572576344
# 8388608 2.5266292840242386
# 8388608 2.513170744292438
# 8388608 2.508364098146558
# 4 exps. , mean loss 2.52113938331604
# P=16777216, batch size=128
# 16777216 2.384321231395006
# 16777216 2.3668707432225347
# 16777216 2.381260048598051
# 16777216 2.37262321729213
# 4 exps. , mean loss 2.3762688636779785
# P=33554432, batch size=128
# 33554432 2.261407311540097
# 33554432 2.2738258675672114
# 33554432 2.253681767731905
# 33554432 2.2659687432460487
# 4 exps. , mean loss 2.263720989227295
# P=67108864, batch size=128
# 67108864 2.168564162682742
# 67108864 2.1667639184743166
# 67108864 2.1754941465333104
# 67108864 2.1814466351643205
# 4 exps. , mean loss 2.173067092895508
# P=134217728, batch size=128
# 134217728 2.1006407644599676
# 134217728 2.0961172110401094
# 134217728 2.1098401369526982
# 134217728 2.104183428455144
# 4 exps. , mean loss 2.1026954650878906
# P=268435456, batch size=128
# 268435456 2.018045333214104
# 268435456 2.04576568165794
# 268435456 2.0383990318514407
# 268435456 2.0274553461931646
# 4 exps. , mean loss 2.032416343688965
# P=529203200, batch size=128
# 529203200 1.9736793311312795
# 529203200 1.9811589261516929
# 529203200 1.9818220878951252
# 529203200 1.9884204301051795
# 4 exps. , mean loss 1.98127019405365

# %%
torch.save(
    {'data': p_list, 'losses': error_list},
    f"tinystories/learning-curves/"+f"learning-curve_tinystories.BPE8192_T{T}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8.pt"
)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

emp_limit_loss = 1.5

ax[0].errorbar([p for p in p_list], [loss.mean() for loss in error_list], yerr=[loss.std() for loss in error_list], color=f'C0', marker='.')
ax[1].errorbar(p_list, [err.mean()-emp_limit_loss for err in error_list], yerr=[err.std() for err in error_list], color=f'C0', marker='.')

ax[0].plot([1e5,1e8],[30*1e5**-(.33/1.8),30*1e8**-(.33/1.8)],'k--')
ax[1].plot([1e5,1e8],[10*1e5**-(.33/1.8),10*1e8**-(.33/1.8)],'k--')
# ax[1].plot([1e6,1e9],[400*1e6**-(.35),400*1e9**-(.35)],'r--')

ax[0].legend(fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax[0].set_xscale('log')
# ax.set_ylim(1.,5.)
ax[0].set_yscale('log')
# ax.set_xlim(1,16)
ax[1].set_xscale('log')
# ax.set_ylim(1.,5.)
ax[1].set_yscale('log')


ax[0].set_ylabel(fr'AR loss', fontsize=11)
ax[0].set_xlabel(fr'training set size $P$', fontsize=11)

fig.tight_layout()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # $n$-grams

# %% [markdown]
# ## Fixed $n$, varying $P$

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)
custom_lines = []
custom_labels = []


vocab_size = 8192
split = 'train'

T = 16
path = f'tinystories/trained/T{T}/'

bs = 128
depth = 12
de = 768
nh = 12
lr = '3e-4'

n = 1

Pmax = 529203200
prefix = f'tinystories.BPE{vocab_size}_T{T}_P{Pmax}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'
collection = collect( path, prefix)

mean_bigram_loss = 0
count = 0
for entry in collection:

    results = torch.load(path+prefix+entry['ending'])
    dynamics = results['dynamics']
    bigram_loss = [d['ngram_loss'][n-1] for d in dynamics]
    ax[0].plot([d['t'] for d in dynamics], bigram_loss, f'k', label=f'P={Pmax}, T={T}')
    final_bi_loss = sum(bigram_loss[-3:])/3.
    ax[1].plot([d['t'] for d in dynamics], [l-final_bi_loss for l in bigram_loss], f'k', label=f'P={P}, T={T}')
    mean_bigram_loss += final_bi_loss
    count += 1

# ax[0].plot([P//(T*bs),P//(T*bs)], [1e0,1e1], f'C{i}', linestyle='dashed')
custom_lines.append(Line2D([0], [0], color=f'k'))
custom_labels.append(fr'$P={Pmax}$, $T={T}$')
mean_bigram_loss /= count
print(P, mean_bigram_loss)


for i,P in enumerate([ 2**18, 2**20, 2**22, 2**24]): 

    prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'
    collection = collect( path, prefix)

    for entry in collection:

        results = torch.load(path+prefix+entry['ending'])
        dynamics = results['dynamics']
        bigram_loss = [d['ngram_loss'][n-1] for d in dynamics]
        ax[0].plot([d['t'] for d in dynamics], bigram_loss, f'C{i}', label=f'P={P}, T={T}')
        ax[1].plot([d['t'] for d in dynamics], [l-mean_bigram_loss for l in bigram_loss], f'C{i}', label=f'P={P}, T={T}')

    ax[0].plot([P//(T*bs),P//(T*bs)], [1e0,1e1], f'C{i}', linestyle='dashed')
    custom_lines.append(Line2D([0], [0], color=f'C{i}'))
    custom_labels.append(fr'$P={P}$, $T={T}$')

ax[0].plot([1e0,1e3],[math.log(8192),math.log(8192)], 'k--')
custom_lines.append(Line2D([0], [0], color='k', linestyle='dashed'))
custom_labels.append(fr'trivial entropy')

marginal = np.load("../SLM/datasets/tinystories/"+f"tinystories.BPE{vocab_size}.{split}_marginal.npy")
marginal = torch.from_numpy(marginal)
marg_ent = torch.masked_select(marginal, (marginal>0))
print(marg_ent.size())
marg_ent = -(marg_ent*marg_ent.log()).sum()
print(marg_ent)
ax[0].plot([1e0,1e3],[marg_ent.cpu(),marg_ent.cpu()], 'r--')
custom_lines.append(Line2D([0], [0], color='r', linestyle='dashed'))
custom_labels.append(fr'marginal entropy')

ax[1].plot([1e1,1e4],[1e1**(-.4),1e4**(-.4)], 'k--')


ax[0].legend(custom_lines, custom_labels, fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax[0].set_xscale('log')
# ax.set_ylim(1.,5.)
ax[0].set_yscale('log')

ax[1].set_xscale('log')
ax[1].set_ylim(1e-2,9.)
ax[1].set_yscale('log')


ax[0].set_ylabel(fr'val loss', fontsize=11)
ax[0].set_xlabel(fr'training step (batch size $={bs}$)', fontsize=11)

fig.tight_layout()
# Out:
# 16777216 tensor(3.5775)
# torch.Size([8130])
# tensor(5.7761)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 1, figsize=(1*5.7, 1*3.6), dpi=120)
custom_lines = []
custom_labels = []


vocab_size = 8192
split = 'train'

T = 16
path = f'tinystories/trained/T{T}/'

bs = 128
depth = 12
de = 768
nh = 12
lr = '3e-4'

# Pmax = 529203200
P = 2**20

for i,n in enumerate([1,2,3,4,6,8,12,16]):

    prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'
    collection = collect( path, prefix)
    for entry in collection:

        results = torch.load(path+prefix+entry['ending'])
        dynamics = results['dynamics']
        ax.plot([d['t'] for d in dynamics], [d['ngram_loss'][n-1] for d in dynamics], f'C{i}', label=f'n={n}, T={T}')
#         print(T, entry['seed'], min([d['val_loss'] for d in dynamics]), results['best']['step'], dynamics[-1]['t'])

    custom_lines.append(Line2D([0], [0], color=f'C{i}'))
    custom_labels.append(fr'$n={n}$, $T={T}$')

ax.plot([1e0,1e3],[math.log(8192),math.log(8192)], 'k--')
custom_lines.append(Line2D([0], [0], color='k', linestyle='dashed'))
custom_labels.append(fr'trivial entropy')

marginal = np.load("../SLM/datasets/tinystories/"+f"tinystories.BPE{vocab_size}.{split}_marginal.npy")
marginal = torch.from_numpy(marginal)
marg_ent = torch.masked_select(marginal, (marginal>0))
print(marg_ent.size())
marg_ent = -(marg_ent*marg_ent.log()).sum()
print(marg_ent)
ax.plot([1e0,1e3],[marg_ent.cpu(),marg_ent.cpu()], 'r--')
custom_lines.append(Line2D([0], [0], color='r', linestyle='dashed'))
custom_labels.append(fr'marginal entropy')


ax.legend(custom_lines, custom_labels, fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax.set_xscale('log')
ax.set_ylim(.8,7.)
ax.set_yscale('log')

ax.set_ylabel(fr'val loss', fontsize=11)
ax.set_xlabel(fr'training step (batch size $={bs}$)', fontsize=11)

fig.tight_layout()
# Out:
# torch.Size([8130])
# tensor(5.7761)

# %%
fig.savefig('tinystories/'+f'ngrams_dynamics_P{P}_T{T}_d12_demb768_nh12_bs{bs}_lr3e-4.pdf')

# %%
def get_ngrams(nmax, path, prefix):

    ngrams_list = []

    p_list = find_all(path, prefix, 'P')
    print('training set sizes: ', p_list)

    for  p in p_list:

        bs = find_lowest(path, prefix, 'bs', f'P{p}_')
        print(f'P={p}, batch size={bs}')
        collection = collect( path, prefix, f'P{p}_', f'bs{bs}_')
        ngrams = []

        for entry in collection:
            try:
                results = torch.load(path+prefix+entry['ending'])
                print(p, results['best']['loss'])
                ngram = torch.zeros(nmax)
                for n in range(nmax):
                    ngram[n] = min([d['ngram_loss'][n] for d in results['dynamics']])
                ngrams.append(ngram)

            except:
                print(path+prefix+entry['ending']+f' not found.')


        print(f'{len(ngrams)} exps. , mean 1-gram {torch.tensor([x[0] for x in ngrams]).mean()}')
        ngrams_list.append(torch.stack(tuple(ngrams)))
    return ngrams_list

vocab_size = 8192
split='train'
T = 16

path = f'tinystories/trained/T{T}/'
ngrams_list = get_ngrams( T, path, f'tinystories.BPE8192_T{T}')
# Out:
# training set sizes:  [32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 529203200]
# P=32768, batch size=128
# 32768 4.467498196288943
# 32768 4.484566682949662
# 32768 4.478424308821559
# 32768 4.5003348384052515
# 4 exps. , mean 1-gram 4.7244553565979
# P=65536, batch size=128
# 65536 4.1203395910561085
# 65536 4.121044358238578
# 65536 4.140920157544315
# 65536 4.111359579488635
# 4 exps. , mean 1-gram 4.413929462432861
# P=131072, batch size=128
# 131072 3.778869517147541
# 131072 3.807228577323258
# 131072 3.787682288326323
# 131072 3.8132656533271074
# 4 exps. , mean 1-gram 4.221348762512207
# P=262144, batch size=128
# 262144 3.532539326697588
# 262144 3.49905947688967
# 262144 3.505987113341689
# 262144 3.4991993606090546
# 4 exps. , mean 1-gram 4.09478235244751
# P=524288, batch size=128
# 524288 3.2452863417565823
# 524288 3.260515664704144
# 524288 3.271410310640931
# 524288 3.273847933858633
# 4 exps. , mean 1-gram 3.9912004470825195
# P=1048576, batch size=128
# 1048576 3.0297282906249166
# 1048576 3.0377580178901553
# 1048576 3.0467962231487036
# 1048576 3.012598969042301
# 4 exps. , mean 1-gram 3.903827667236328
# P=2097152, batch size=128
# 2097152 2.836450058966875
# 2097152 2.8710661260411143
# 2097152 2.8435717979446054
# 2097152 2.8365645008161664
# 4 exps. , mean 1-gram 3.848435878753662
# P=4194304, batch size=128
# 4194304 2.6913719521835446
# 4194304 2.67446222435683
# 4194304 2.699439018033445
# 4194304 2.6785543989390135
# 4 exps. , mean 1-gram 3.7937021255493164
# P=8388608, batch size=128
# 8388608 2.536393572576344
# 8388608 2.5266292840242386
# 8388608 2.513170744292438
# 8388608 2.508364098146558
# 4 exps. , mean 1-gram 3.736088275909424
# P=16777216, batch size=128
# 16777216 2.384321231395006
# 16777216 2.3668707432225347
# 16777216 2.381260048598051
# 16777216 2.37262321729213
# 4 exps. , mean 1-gram 3.673366069793701
# P=33554432, batch size=128
# 33554432 2.261407311540097
# 33554432 2.2738258675672114
# 33554432 2.253681767731905
# 33554432 2.2659687432460487
# 4 exps. , mean 1-gram 3.624556541442871
# P=67108864, batch size=128
# 67108864 2.168564162682742
# 67108864 2.1667639184743166
# 67108864 2.1754941465333104
# 67108864 2.1814466351643205
# 4 exps. , mean 1-gram 3.6063437461853027
# P=134217728, batch size=128
# 134217728 2.1006407644599676
# 134217728 2.0961172110401094
# 134217728 2.1098401369526982
# 134217728 2.104183428455144
# 4 exps. , mean 1-gram 3.6057591438293457
# P=268435456, batch size=128
# 268435456 2.018045333214104
# 268435456 2.04576568165794
# 268435456 2.0383990318514407
# 268435456 2.0274553461931646
# 4 exps. , mean 1-gram 3.6016392707824707
# P=529203200, batch size=128
# 529203200 1.9736793311312795
# 529203200 1.9811589261516929
# 529203200 1.9818220878951252
# 529203200 1.9884204301051795
# 4 exps. , mean 1-gram 3.576119899749756

# %%
torch.save(
    {'data': p_list, 'ngrams': error_list},
    f"tinystories/learning-curves/"+f"ngrams_tinystories.BPE8192_T{T}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8.pt"
)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

ax[0].plot([p for p in p_list], [loss.mean() for loss in error_list], 'r--')

for i, n in enumerate([1,2,3,4,6,8,12,16]):

    ax[0].plot([p for p in p_list], [loss[:,n-1].mean() for loss in ngrams_list], f'C{i}',  marker='.', label=f'n={n}')
    ax[1].plot([p/(n**(1./(2*.872))) for p in p_list], [loss[:,n-1].mean()*(n**.25/(2*.872)) for loss in ngrams_list], f'C{i}',  marker='.', label=f'n={n}')

ax[0].plot([3e4,3e7],[100*3e4**-.25,100*3e7**-.25],'k--')

ax[0].legend(fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax[0].set_xscale('log')
ax[0].set_ylim(1.,8.)
ax[0].set_yscale('log')

ax[1].set_xscale('log')
# # ax.set_ylim(1.,5.)
ax[1].set_yscale('log')

ax[0].set_ylabel(fr'n-gram loss', fontsize=11)
ax[0].set_xlabel(fr'training set size $P$', fontsize=11)

fig.tight_layout()

# %%
fig.savefig('tinystories/'+f'ngrams-scaling_tinystories.BPE8192_T{T}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8.pdf')

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

# ax[0].plot([p for p in p_list], [loss.mean() for loss in error_list], 'r--')
floor_list = []

for i, p in enumerate(p_list):

    ax[0].plot([i+1 for i in range(T)], ngrams_list[i].mean(dim=0), f'C{i}',  marker='.', label=f'P={p}')
    floor = ngrams_list[i][:,-4:].mean()
    floor_list.append(floor)
    ax[0].plot([i+1 for i in range(T)], [floor for _ in range(T)], f'C{i}',  linestyle='dashed')

ax[1].plot(p_list,floor_list,'k--')

ax[0].legend(fontsize=8, handlelength=1)
ax[0].set_xlim(.7,512)
ax[0].set_xscale('log')
ax[0].set_ylim(.9,6.)
ax[0].set_yscale('log')

ax[1].set_xlim(2**17, 2**30)
ax[1].set_xscale('log')
ax[1].set_ylim(1.,5.)
ax[1].set_yscale('log')

ax[0].set_ylabel(fr'n-gram loss', fontsize=11)
ax[0].set_xlabel(fr'training set size $P$', fontsize=11)

fig.tight_layout()
