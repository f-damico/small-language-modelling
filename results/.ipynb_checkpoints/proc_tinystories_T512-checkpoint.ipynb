# %%
import os
import sys
import time
import copy
sys.path.append('../SLM/')

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import json
import math
import random

import fnmatch
import re
from itertools import product, groupby

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from tokenizers import Tokenizer

import models, init, train, measures
import importlib
# Reload the modules
importlib.reload( models)

device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(device)

def collect(path, prefix, *keys):

    all_entries = os.listdir(path)
    matching_entries = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
#                 params = re.findall(r'_P(\d+)', ending)
#                 assert params, f'{entry}: trainsize p not found!'
                array = re.findall(r'_(\d+)', ending)
                matching_entries.append({
                    'ending': ending,
#                     'P': int(params[0]),
                    'seed': int(array[0])
                })
#     matching_entries.sort(key=lambda x: [x.get('P'), x.get('exp')])
    return matching_entries


def find_all(path, prefix, what, *keys):
    
    all_entries = os.listdir(path)
    params = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
                param = re.findall(what+r'(\d+)', ending)
                param = int(param[0])
                if param not in params:
                    params.append(param)
    params.sort()
    return params


def find_lowest(path, prefix, what, *keys):
    
    all_entries = os.listdir(path)
    params = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
                param = re.findall(what+r'(\d+)', ending)
                param = int(param[0])
                if param not in params:
                    params.append(param)
    params.sort()
    return params[0]


def get_loss(path, prefix):

    loss_list = []

    p_list = find_all(path, prefix, 'P')
    print('training set sizes: ', p_list)

    for  p in p_list:

        bs = find_lowest(path, prefix, 'bs', f'P{p}_')
        print(f'P={p}, batch size={bs}')
        collection = collect( path, prefix, f'P{p}_', f'bs{bs}_')
        loss = []

        for entry in collection:
            try:
                results = torch.load(path+prefix+entry['ending'])
                print(p, results['best']['loss'])
                loss.append(results['best']['loss'])

            except:
                print(path+prefix+entry['ending']+f' not found.')


        print(f'{len(loss)} exps. , mean loss {torch.tensor(loss).mean()}')
        loss_list.append(torch.tensor(loss))
    return loss_list


fig, ax = plt.subplots(1, 2, figsize=(20,5.0))
# Out:
# cuda

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 1, figsize=(1*5.7, 1*3.6), dpi=120)
custom_lines = []
custom_labels = []


vocab_size = 8192
split = 'train'

T = 512
path = f'tinystories/trained/T{T}/'

bs = 32
depth = 12
de = 768
nh = 12
lr = '3e-4'

n=16

for i,P in enumerate([ 2**20, 2**21, 2**22, 2**23, 2**24, 2**25, 2**26, 2**27, 2**28, 529203200]): 

#     if P <= 2**21:
#         dt = 2048
#     else:
#         dt = (P//(T*bs))*8
    prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'#_dt{dt}'
    collection = collect( path, prefix)
    for entry in collection:

        results = torch.load(path+prefix+entry['ending'])
        dynamics = results['dynamics']
        ax.plot([d['t'] for d in dynamics], [d['val_loss'] for d in dynamics], f'C{i}', label=f'P={P}, T={T}')
        print(T, entry['seed'], min([d['val_loss'] for d in dynamics]), results['best']['step'], dynamics[-1]['t'])
    ax.plot([P//(T*bs),P//(T*bs)], [1e0,1e1], f'C{i}', linestyle='dashed')
    custom_lines.append(Line2D([0], [0], color=f'C{i}'))
    custom_labels.append(fr'$P={P}$, $T={T}$')

ax.plot([1e0,1e3],[math.log(8192),math.log(8192)], 'k--')
custom_lines.append(Line2D([0], [0], color='k', linestyle='dashed'))
custom_labels.append(fr'trivial entropy')

marginal = np.load("../SLM/datasets/tinystories/"+f"tinystories.BPE{vocab_size}.{split}_marginal.npy")
marginal = torch.from_numpy(marginal)
marg_ent = torch.masked_select(marginal, (marginal>0))
print(marg_ent.size())
marg_ent = -(marg_ent*marg_ent.log()).sum()
print(marg_ent)
ax.plot([1e0,1e3],[marg_ent.cpu(),marg_ent.cpu()], 'r--')
custom_lines.append(Line2D([0], [0], color='r', linestyle='dashed'))
custom_labels.append(fr'marginal entropy')


ax.legend(custom_lines, custom_labels, fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax.set_xscale('log')
# ax.set_ylim(1.,5.)
ax.set_yscale('log')

ax.set_ylabel(fr'val loss', fontsize=11)
ax.set_xlabel(fr'training step (batch size $={bs}$)', fontsize=11)

fig.tight_layout()
# Out:
# 512 13270678 3.6149500384926796 511 4096
# 512 12298471 3.6247934624552727 511 4096
# 512 1906838 3.613776534795761 511 4096
# 512 10425152 3.6373987421393394 723 4096
# 512 4039267 3.090768478810787 1447 4096
# 512 4664038 3.0780876874923706 1447 4096
# 512 1132608 3.078489415347576 1447 4096
# 512 6252540 3.088910810649395 1447 4096
# 512 10582134 2.602642022073269 2895 4096
# 512 2663105 2.5863496139645576 2895 4096
# 512 9550838 2.5673137605190277 2895 4096
# 512 3308477 2.5854799896478653 2895 4096
# 512 14975959 2.0951716154813766 4095 8192
# 512 5026102 2.128808431327343 4095 8192
# 512 2005069 2.105803959071636 4095 8192
# 512 12499693 2.1454648077487946 4095 8192
# 512 5505925 1.8462261147797108 7167 16384
# 512 330491 1.836507387459278 7167 16384
# 512 10620756 1.8364216573536396 7167 16384
# 512 8461114 1.846852544695139 7167 16384
# 512 5463457 1.6266865208745003 13311 34816
# 512 16380171 1.6351705603301525 14335 34816
# 512 10799095 1.629823710769415 14335 34816
# 512 6744741 1.6402218453586102 12287 34816
# 512 5388458 1.4583860523998737 28671 65536
# 512 15441961 1.4756484925746918 27647 65536
# 512 4886624 1.459551751613617 27647 65536
# 512 9788849 1.475974965840578 27647 65536
# 512 4068787 1.3217289000749588 59391 131072
# 512 6587050 1.3104859180748463 56319 131072
# 512 9096996 1.3154736198484898 60415 131072
# 512 16110734 1.3188926577568054 52223 93184
# 512 13003059 1.2147866822779179 124927 262144
# 512 6306426 1.202145591378212 129023 262144
# 512 14133285 1.199149664491415 122879 262144
# 512 16290335 1.2284009642899036 129023 262144
# 512 11505416 1.1378853730857372 331775 524288
# 512 3341173 1.140166237950325 280575 524288
# 512 6049935 1.1268133968114853 289791 524288
# 512 1023736 1.1244906708598137 258047 524288
# torch.Size([8130])
# tensor(5.7761)

# %%
fig.savefig('tinystories/'+f'dynamics-vs-num-data_T{T}_d12_demb768_nh12_bs{bs}_lr3e-4.pdf')

# %%
P = 529203200
dt = (P//(T*bs))*8
prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8_dt{dt}'
collection = collect( path, prefix)
for entry in collection:

    results = torch.load(path+prefix+entry['ending'])
    trained = results['best']['model']
    print(results.keys())
    print(results['best'].keys())
# Out:
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])
# dict_keys(['config', 'dynamics', 'best'])
# dict_keys(['step', 'loss', 'model'])

# %% [markdown]
# # LEARNING CURVE (loss vs num. data)

# %%
vocab_size = 8192
split='train'
T = 512
path = f'tinystories/trained/T{T}/'

error_list = get_loss(path, f'tinystories.BPE8192_T{T}')
p_list = find_all(path, f'tinystories.BPE8192_T{T}', 'P')
# Out:
# training set sizes:  [131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 529203200]
# P=131072, batch size=32
# 131072 4.18038384616375
# 131072 4.182666838169098
# 131072 4.202223062515259
# 131072 4.187371373176575
# 4 exps. , mean loss 4.1881608963012695
# P=262144, batch size=32
# 262144 4.012065626680851
# 262144 4.047535344958305
# 262144 4.0266241282224655
# 262144 4.065017282962799
# 4 exps. , mean loss 4.037810802459717
# P=524288, batch size=32
# 524288 3.8992356806993484
# 524288 3.8893355056643486
# 524288 3.8969599306583405
# 524288 3.9150908142328262
# 4 exps. , mean loss 3.900155544281006
# P=1048576, batch size=32
# 1048576 3.6149500384926796
# 1048576 3.6247934624552727
# 1048576 3.613776534795761
# 1048576 3.6373987421393394
# 4 exps. , mean loss 3.622729539871216
# P=2097152, batch size=32
# 2097152 3.090768478810787
# 2097152 3.0780876874923706
# 2097152 3.078489415347576
# 2097152 3.088910810649395
# 4 exps. , mean loss 3.084064245223999
# P=4194304, batch size=32
# 4194304 2.602642022073269
# 4194304 2.5863496139645576
# 4194304 2.5673137605190277
# 4194304 2.5854799896478653
# 4 exps. , mean loss 2.585446357727051
# P=8388608, batch size=32
# 8388608 2.0951716154813766
# 8388608 2.128808431327343
# 8388608 2.105803959071636
# 8388608 2.1454648077487946
# 4 exps. , mean loss 2.118812084197998
# P=16777216, batch size=32
# 16777216 1.8408148661255836
# 16777216 1.833255834877491
# 16777216 1.833467923104763
# 16777216 1.8436817862093449
# 4 exps. , mean loss 1.837805151939392
# P=33554432, batch size=32
# 33554432 1.6219476461410522
# 33554432 1.6284907758235931
# 33554432 1.6242146641016006
# 33554432 1.6325067542493343
# 4 exps. , mean loss 1.626789927482605
# P=67108864, batch size=32
# 67108864 1.457202523946762
# 67108864 1.4726149030029774
# 67108864 1.456681925803423
# 67108864 1.472723100334406
# 4 exps. , mean loss 1.4648056030273438
# P=134217728, batch size=32
# 134217728 1.3175007663667202
# 134217728 1.3067555874586105
# 134217728 1.3115715682506561
# 134217728 1.3146466426551342
# 4 exps. , mean loss 1.312618613243103
# P=268435456, batch size=32
# 268435456 1.2134347148239613
# 268435456 1.200666144490242
# 268435456 1.1976573579013348
# 268435456 1.2274028547108173
# 4 exps. , mean loss 1.2097902297973633
# P=529203200, batch size=32
# 529203200 1.1372561380267143
# 529203200 1.1393853724002838
# 529203200 1.1268000230193138
# 529203200 1.123956099152565
# 4 exps. , mean loss 1.1318494081497192

# %%
torch.save(
    {'data': p_list, 'losses': error_list},
    f"tinystories/learning-curves/"+f"learning-curve_tinystories.BPE8192_T{T}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8.pt"
)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

emp_limit_loss = 0.7

ax[0].errorbar([p for p in p_list], [loss.mean() for loss in error_list], yerr=[loss.std() for loss in error_list], color=f'C0', marker='.')
ax[1].errorbar(p_list, [err.mean()-emp_limit_loss for err in error_list], yerr=[err.std() for err in error_list], color=f'C0', marker='.')

ax[0].plot([1e5,1e8],[30*1e5**-(.33/1.8),30*1e8**-(.33/1.8)],'k--')
ax[1].plot([1e5,1e8],[10*1e5**-(.33/1.8),10*1e8**-(.33/1.8)],'k--')
ax[1].plot([1e6,1e9],[400*1e6**-(.3),400*1e9**-(.3)],'r--')

ax[0].legend(fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax[0].set_xscale('log')
# ax.set_ylim(1.,5.)
ax[0].set_yscale('log')
# ax.set_xlim(1,16)
ax[1].set_xscale('log')
# ax.set_ylim(1.,5.)
ax[1].set_yscale('log')


ax[0].set_ylabel(fr'AR loss', fontsize=11)
ax[0].set_xlabel(fr'training set size $P$', fontsize=11)

fig.tight_layout()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # $n$-grams

# %% [markdown]
# ## Fixed $n$, varying $P$

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)
custom_lines = []
custom_labels = []


vocab_size = 8192
split = 'train'

T = 512
path = f'tinystories/trained/T{T}/'

bs = 32
depth = 12
de = 768
nh = 12
lr = '3e-4'

n = 1

Pmax = 529203200
prefix = f'tinystories.BPE{vocab_size}_T{T}_P{Pmax}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'
collection = collect( path, prefix)

mean_bigram_loss = 0
count = 0
for entry in collection:

    results = torch.load(path+prefix+entry['ending'])
    dynamics = results['dynamics']
    bigram_loss = [d['ngram_loss'][n-1] for d in dynamics]
    ax[0].plot([d['t'] for d in dynamics], bigram_loss, f'k', label=f'P={Pmax}, T={T}')
    final_bi_loss = sum(bigram_loss[-3:])/3.
    ax[1].plot([d['t'] for d in dynamics], [l-final_bi_loss for l in bigram_loss], f'k', label=f'P={P}, T={T}')
    mean_bigram_loss += final_bi_loss
    count += 1

# ax[0].plot([P//(T*bs),P//(T*bs)], [1e0,1e1], f'C{i}', linestyle='dashed')
custom_lines.append(Line2D([0], [0], color=f'k'))
custom_labels.append(fr'$P={Pmax}$, $T={T}$')
mean_bigram_loss /= count
print(P, mean_bigram_loss)


for i,P in enumerate([ 2**20, 2**22, 2**24, 2**26, 2**28]): 

    prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'
    collection = collect( path, prefix)

    for entry in collection:

        results = torch.load(path+prefix+entry['ending'])
        dynamics = results['dynamics']
        bigram_loss = [d['ngram_loss'][n-1] for d in dynamics]
        ax[0].plot([d['t'] for d in dynamics], bigram_loss, f'C{i}', label=f'P={P}, T={T}')
        ax[1].plot([d['t'] for d in dynamics], [l-mean_bigram_loss for l in bigram_loss], f'C{i}', label=f'P={P}, T={T}')

    ax[0].plot([P//(T*bs),P//(T*bs)], [1e0,1e1], f'C{i}', linestyle='dashed')
    custom_lines.append(Line2D([0], [0], color=f'C{i}'))
    custom_labels.append(fr'$P={P}$, $T={T}$')

ax[0].plot([1e0,1e3],[math.log(8192),math.log(8192)], 'k--')
custom_lines.append(Line2D([0], [0], color='k', linestyle='dashed'))
custom_labels.append(fr'trivial entropy')

marginal = np.load("../SLM/datasets/tinystories/"+f"tinystories.BPE{vocab_size}.{split}_marginal.npy")
marginal = torch.from_numpy(marginal)
marg_ent = torch.masked_select(marginal, (marginal>0))
print(marg_ent.size())
marg_ent = -(marg_ent*marg_ent.log()).sum()
print(marg_ent)
ax[0].plot([1e0,1e3],[marg_ent.cpu(),marg_ent.cpu()], 'r--')
custom_lines.append(Line2D([0], [0], color='r', linestyle='dashed'))
custom_labels.append(fr'marginal entropy')

ax[1].plot([1e1,1e4],[1e1**(-.4),1e4**(-.4)], 'k--')


ax[0].legend(custom_lines, custom_labels, fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax[0].set_xscale('log')
# ax.set_ylim(1.,5.)
ax[0].set_yscale('log')

ax[1].set_xscale('log')
ax[1].set_ylim(1e-2,9.)
ax[1].set_yscale('log')


ax[0].set_ylabel(fr'val loss', fontsize=11)
ax[0].set_xlabel(fr'training step (batch size $={bs}$)', fontsize=11)

fig.tight_layout()
# Out:
# 529203200 tensor(3.6142)
# torch.Size([8130])
# tensor(5.7761)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 1, figsize=(1*5.7, 1*3.6), dpi=120)
custom_lines = []
custom_labels = []


vocab_size = 8192
split = 'train'

T = 512
path = f'tinystories/trained/T{T}/'

bs = 32
depth = 12
de = 768
nh = 12
lr = '3e-4'

# Pmax = 529203200
P = 2**24

for i,n in enumerate([1,2,3,4,6,8,12,16,24,32]):

    prefix = f'tinystories.BPE{vocab_size}_T{T}_P{P}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8'
    collection = collect( path, prefix)
    for entry in collection:

        results = torch.load(path+prefix+entry['ending'])
        dynamics = results['dynamics']
        ax.plot([d['t'] for d in dynamics], [d['ngram_loss'][n-1] for d in dynamics], f'C{i}', label=f'n={n}, T={T}')
#         print(T, entry['seed'], min([d['val_loss'] for d in dynamics]), results['best']['step'], dynamics[-1]['t'])

    custom_lines.append(Line2D([0], [0], color=f'C{i}'))
    custom_labels.append(fr'$n={n}$, $T={T}$')

ax.plot([1e0,1e3],[math.log(8192),math.log(8192)], 'k--')
custom_lines.append(Line2D([0], [0], color='k', linestyle='dashed'))
custom_labels.append(fr'trivial entropy')

marginal = np.load("../SLM/datasets/tinystories/"+f"tinystories.BPE{vocab_size}.{split}_marginal.npy")
marginal = torch.from_numpy(marginal)
marg_ent = torch.masked_select(marginal, (marginal>0))
print(marg_ent.size())
marg_ent = -(marg_ent*marg_ent.log()).sum()
print(marg_ent)
ax.plot([1e0,1e3],[marg_ent.cpu(),marg_ent.cpu()], 'r--')
custom_lines.append(Line2D([0], [0], color='r', linestyle='dashed'))
custom_labels.append(fr'marginal entropy')


ax.legend(custom_lines, custom_labels, fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax.set_xscale('log')
ax.set_ylim(.8,7.)
ax.set_yscale('log')

ax.set_ylabel(fr'val loss', fontsize=11)
ax.set_xlabel(fr'training step (batch size $={bs}$)', fontsize=11)

fig.tight_layout()
# Out:
# torch.Size([8130])
# tensor(5.7761)

# %%
fig.savefig('tinystories/'+f'ngrams_dynamics_P{P}_T{T}_d12_demb768_nh12_bs{bs}_lr3e-4.pdf')

# %%
def get_ngrams(nmax, path, prefix):

    ngrams_list = []

    p_list = find_all(path, prefix, 'P')
    print('training set sizes: ', p_list)

    for  p in p_list:

        bs = find_lowest(path, prefix, 'bs', f'P{p}_')
        print(f'P={p}, batch size={bs}')
        collection = collect( path, prefix, f'P{p}_', f'bs{bs}_')
        ngrams = []

        for entry in collection:
            try:
                results = torch.load(path+prefix+entry['ending'])
                print(p, results['best']['loss'])
                ngram = torch.zeros(nmax)
                for n in range(nmax):
                    ngram[n] = min([d['ngram_loss'][n] for d in results['dynamics']])
                ngrams.append(ngram)

            except:
                print(path+prefix+entry['ending']+f' not found.')


        print(f'{len(ngrams)} exps. , mean 1-gram {torch.tensor([x[0] for x in ngrams]).mean()}')
        ngrams_list.append(torch.stack(tuple(ngrams)))
    return ngrams_list

vocab_size = 8192
split='train'
T = 512

path = f'tinystories/trained/T{T}/'
ngrams_list = get_ngrams( T, path, f'tinystories.BPE8192_T{T}')
# Out:
# training set sizes:  [131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 529203200]
# P=131072, batch size=32
# 131072 4.18038384616375
# 131072 4.182666838169098
# 131072 4.202223062515259
# 131072 4.187371373176575
# 4 exps. , mean 1-gram 4.737642765045166
# P=262144, batch size=32
# 262144 4.012065626680851
# 262144 4.047535344958305
# 262144 4.0266241282224655
# 262144 4.065017282962799
# 4 exps. , mean 1-gram 4.465394020080566
# P=524288, batch size=32
# 524288 3.8992356806993484
# 524288 3.8893355056643486
# 524288 3.8969599306583405
# 524288 3.9150908142328262
# 4 exps. , mean 1-gram 4.385713577270508
# P=1048576, batch size=32
# 1048576 3.6149500384926796
# 1048576 3.6247934624552727
# 1048576 3.613776534795761
# 1048576 3.6373987421393394
# 4 exps. , mean 1-gram 4.206465721130371
# P=2097152, batch size=32
# 2097152 3.090768478810787
# 2097152 3.0780876874923706
# 2097152 3.078489415347576
# 2097152 3.088910810649395
# 4 exps. , mean 1-gram 3.9977593421936035
# P=4194304, batch size=32
# 4194304 2.602642022073269
# 4194304 2.5863496139645576
# 4194304 2.5673137605190277
# 4194304 2.5854799896478653
# 4 exps. , mean 1-gram 3.9470207691192627
# P=8388608, batch size=32
# 8388608 2.0951716154813766
# 8388608 2.128808431327343
# 8388608 2.105803959071636
# 8388608 2.1454648077487946
# 4 exps. , mean 1-gram 3.9936630725860596
# P=16777216, batch size=32
# 16777216 1.8408148661255836
# 16777216 1.833255834877491
# 16777216 1.833467923104763
# 16777216 1.8436817862093449
# 4 exps. , mean 1-gram 3.8490219116210938
# P=33554432, batch size=32
# 33554432 1.6219476461410522
# 33554432 1.6284907758235931
# 33554432 1.6242146641016006
# 33554432 1.6325067542493343
# 4 exps. , mean 1-gram 3.793612480163574
# P=67108864, batch size=32
# 67108864 1.457202523946762
# 67108864 1.4726149030029774
# 67108864 1.456681925803423
# 67108864 1.472723100334406
# 4 exps. , mean 1-gram 3.6769721508026123
# P=134217728, batch size=32
# 134217728 1.3175007663667202
# 134217728 1.3067555874586105
# 134217728 1.3115715682506561
# 134217728 1.3146466426551342
# 4 exps. , mean 1-gram 3.726435661315918
# P=268435456, batch size=32
# 268435456 1.2134347148239613
# 268435456 1.200666144490242
# 268435456 1.1976573579013348
# 268435456 1.2274028547108173
# 4 exps. , mean 1-gram 3.6642305850982666
# P=529203200, batch size=32
# 529203200 1.1372561380267143
# 529203200 1.1393853724002838
# 529203200 1.1268000230193138
# 529203200 1.123956099152565
# 4 exps. , mean 1-gram 3.6110029220581055

# %%
torch.save(
    {'data': p_list, 'ngrams': error_list},
    f"tinystories/learning-curves/"+f"ngrams_tinystories.BPE8192_T{T}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8.pt"
)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

ax[0].plot([p for p in p_list], [loss.mean() for loss in error_list], 'r--')

for i, n in enumerate([1,2,3,4,6,8,12,16,24,32,48,64,96,128,192,256,386,512]):

    ax[0].plot([p for p in p_list], [loss[:,n-1].mean() for loss in ngrams_list], f'C{i}',  marker='.', label=f'n={n}')
    ax[1].plot([p/(n**(1./(2*.872))) for p in p_list[3:]], [loss[:,n-1].mean()*(n**.25/(2*.872)) for loss in ngrams_list[3:]], f'C{i}',  marker='.', label=f'n={n}')

ax[0].plot([3e4,3e7],[100*3e4**-.25,100*3e7**-.25],'k--')

ax[0].legend(fontsize=8, handlelength=1)
# ax.set_xlim(1,16)
ax[0].set_xscale('log')
ax[0].set_ylim(1.,8.)
ax[0].set_yscale('log')

ax[1].set_xscale('log')
# # ax.set_ylim(1.,5.)
ax[1].set_yscale('log')

ax[0].set_ylabel(fr'n-gram loss', fontsize=11)
ax[0].set_xlabel(fr'training set size $P$', fontsize=11)

fig.tight_layout()

# %%
fig.savefig('tinystories/'+f'ngrams-scaling_tinystories.BPE8192_T{T}_d{depth}_demb{de}_nh{nh}_bs{bs}_lr{lr}_wt8.pdf')

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

# ax[0].plot([p for p in p_list], [loss.mean() for loss in error_list], 'r--')
floor_list = []

for i, p in enumerate(p_list):

    ax[0].plot([i+1 for i in range(T)], ngrams_list[i].mean(dim=0), f'C{i}',  marker='.', label=f'P={p}')
    floor = ngrams_list[i][:,-64:].mean()
    floor_list.append(floor)
    ax[0].plot([i+1 for i in range(T)], [floor for _ in range(T)], f'C{i}',  linestyle='dashed')

ax[1].plot(p_list,floor_list,'k--')

ax[0].legend(fontsize=8, handlelength=1)
ax[0].set_xlim(.7,512)
ax[0].set_xscale('log')
ax[0].set_ylim(.9,6.)
ax[0].set_yscale('log')

ax[1].set_xlim(2**17, 2**30)
ax[1].set_xscale('log')
ax[1].set_ylim(1.,5.)
ax[1].set_yscale('log')

ax[0].set_ylabel(fr'n-gram loss', fontsize=11)
ax[0].set_xlabel(fr'training set size $P$', fontsize=11)

fig.tight_layout()
