# %%
import os
import sys
import time
import copy
sys.path.append('../SLM/')

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import json
import math
import random

import fnmatch
import re
from itertools import product, groupby

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from tokenizers import Tokenizer

import models, init, train, measures
import importlib
# Reload the modules
importlib.reload( models)

device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(device)

def collect(path, prefix, *keys):

    all_entries = os.listdir(path)
    matching_entries = []
    for entry in all_entries:

        if fnmatch.fnmatch(entry, prefix+'*'):

            check_keys = 1
            for key in keys:
                check_keys *= fnmatch.fnmatch(entry, '*'+key+'*')
            if check_keys:
                ending = re.sub(prefix, '', entry)
#                 params = re.findall(r'_P(\d+)', ending)
#                 assert params, f'{entry}: trainsize p not found!'
                array = re.findall(r'_(\d+)', ending)
                matching_entries.append({
                    'ending': ending,
#                     'P': int(params[0]),
                    'seed': int(array[0])
                })
#     matching_entries.sort(key=lambda x: [x.get('P'), x.get('exp')])
    return matching_entries

fig, ax = plt.subplots(1, 2, figsize=(20,5.0))
# Out:
# cuda

# %%
vocab_size = 8192
split = 'train'
max_dist = 2049
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE8192.train_d{max_dist}"

dist = 2048

import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(6.5,5))

x_pts = [2**exp for exp in range(15, 29)]
y_pts = []
for x in x_pts:
    results = torch.load(path+prefix+f"_t{dist}_P{x}.pt")
    y_pts.append(results['corr'].cpu())

ax.plot(x_pts, y_pts)


ax.plot(x_pts, [x**(-.5)/(vocab_size) for x in x_pts], 'k--')

ax.set_xscale('log')
ax.set_yscale('log')

# %%
vocab_size = 8192
split = 'train'
max_dist = 1025
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE8192.train_d{max_dist}"

dist = 16
x = 2**15

results = torch.load(path+prefix+f"_t{dist}_P{x}.pt")
print(results['cov'].size())
corr = results['cov'] - results['right'][:,None] @ results['left'][None,:]
print(x, results['corr'], corr.std(), 1./(vocab_size*x**.5) )

# %%
# %%time
svals = torch.linalg.svdvals(corr)

# Direct diagonalisation C^\top C: not as stable 
# A = (corr.t() @ corr)
# eigvals, eigvecs = torch.linalg.eigh( A)

torch.save(
    {'P': x, 'svals': svals},
    path + f"CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}_P{x}.pt"
)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
fig, ax = plt.subplots(1, 1, figsize=(2*3.8, 1.5*2.4), dpi=120)

svals_sorted, indices_sorted = torch.sort(svals, descending=True)
ax.plot( 1+torch.arange(svals_sorted.size(0)), svals_sorted, f'C0')
print((svals_sorted**2).sum()**.5/(8192),results['corr'])
ax.plot( 1+torch.arange(svals_sorted.size(0)), [1./(vocab_size*x**.5) for _ in torch.arange(svals_sorted.size(0))], f'C0', linestyle='dashed')

# eigvals_sorted, indices_sorted = torch.sort(eigvals.abs().sqrt(), descending=True)
# ax.plot( 1+torch.arange(eigvals_sorted.size(0)), eigvals_sorted, f'C1')
# print((eigvals_sorted**2).sum(), results['corr'])

ax.set_yscale('log')
ax.set_xscale('log')

# %% [markdown]
# ## UNIGRAM DISTRIBUTION

# %% [markdown]
# ## RANKED SPECTRA (SVD)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
fig, ax = plt.subplots(1, 3, figsize=(4*3.8, 1.5*2.4), dpi=120)

vocab_size = 8192
split = 'train'
max_dist = 1025
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE{vocab_size}.{split}_d{max_dist}"


dist = 192
p_list = [ 2**exp for exp in range(15,29)]
onorm_list = []
fnorm_list = []

for i, p in enumerate(p_list):

    spectrum = torch.load(path + f"CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}_P{p}.pt")
    svals = spectrum['S']
    svals_sorted, indices_sorted = torch.sort(svals, descending=True)
    onorm_list.append(svals_sorted[0])
    fnorm_list.append((svals_sorted**2).sum()**.5)
    print(p, svals_sorted[0], (svals_sorted**2).sum()**.5)
    exponent = int(math.log(p)/math.log(2))
    ax[0].plot( 1+torch.arange(svals.size(0)), svals_sorted, f'C{i}', label=fr'$P=2^{exponent}$')
    ax[1].plot( 1+torch.arange(svals.size(0)), svals_sorted*p**.5, f'C{i}', label=fr'$P=2^{{exponent}}$')

gamma = 1.
G = 1e-1
ax[0].plot([1e1, 1e3], [G*1e1**(-gamma), G*1e3**(-gamma)], 'k--', label='$k^{-1}$')

ax[0].set_yscale('log')
ax[0].set_xscale('log')
ax[0].set_ylabel('singular values $\sigma_k$', fontsize=11)
ax[0].set_xlabel('rank $k$', fontsize=11)
ax[0].legend( fontsize=8, handlelength=1, loc='upper right')
ax[0].set_xlim(1,8192*8)
ax[0].set_ylim(1e-8,2e-2)

ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_ylabel('$\sqrt{P}\sigma_k$', fontsize=11)
ax[1].set_xlabel('rank $k$', fontsize=11)
ax[1].set_xlim(1,8192)
ax[1].set_ylim(1e-4,1e4)

ax[2].plot(p_list, onorm_list, f'C0', label='op. norm ($\sigma_1$)')
ax[2].plot(p_list, fnorm_list, f'C1', label='Fr. norm ($\mathrm{rms}(\sigma_i)$)')
ax[2].plot([p for p in p_list[:5]], [p**(-.5) for p in p_list[:5]] , 'k--', label=r'$P^{-1/2}')
fit_f = np.polyfit(np.log(np.array(p_list[-5:])), np.log(np.array(fnorm_list[-5:])), 1)
fit_o = np.polyfit(np.log(np.array(p_list[-5:])), np.log(np.array(onorm_list[-5:])), 1)
print(fit_o, fit_f)
# ax[1].plot(p_list, [o*math.sqrt(vocab_size) for o in onorm_list], f'C2', label='scaled op. norm')
ax[2].set_yscale('log')
ax[2].set_xscale('log')
ax[2].set_xlabel('sample size $P$', fontsize=11)
ax[2].legend( fontsize=8, handlelength=1)
# Out:
# 32768 tensor(0.0018) tensor(0.0055)
# 65536 tensor(0.0012) tensor(0.0039)
# 131072 tensor(0.0009) tensor(0.0028)
# 262144 tensor(0.0006) tensor(0.0019)
# 524288 tensor(0.0005) tensor(0.0014)
# 1048576 tensor(0.0004) tensor(0.0011)
# 2097152 tensor(0.0004) tensor(0.0008)
# 4194304 tensor(0.0004) tensor(0.0006)
# 8388608 tensor(0.0003) tensor(0.0005)
# 16777216 tensor(0.0003) tensor(0.0005)
# 33554432 tensor(0.0003) tensor(0.0004)
# 67108864 tensor(0.0003) tensor(0.0004)
# 134217728 tensor(0.0003) tensor(0.0004)
# 268435456 tensor(0.0003) tensor(0.0004)
# [-0.01003484 -7.88363647] [-0.05628738 -6.75274239]

# %%
fig.savefig(f'CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}.pdf')

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
fig, ax = plt.subplots(1, 2, figsize=(2*3.8, 1*2.4), dpi=120)

vocab_size = 8192
split = 'train'
max_dist = 1025
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE{vocab_size}.{split}_d{max_dist}"

# unigram = torch.load("tinystories/"+f"unigram_tinystories.BPE8192.{split}.pt")
# unigram_cov = torch.diag(unigram)-unigram[:,None] @ unigram[None]
# svals = torch.linalg.svdvals(unigram_cov)
# svals_sorted, _ = torch.sort(svals, descending=True)
# ax[0].plot( 1+torch.arange(svals_sorted.size(0)), svals_sorted, f'k--', label=fr'$t={0}$')

p = 2**28
d_list = [1,2,3,4,6,8,12,16,24,32,48,64,96,128,192,256,512]
# dist = 2048
# p_list = [ 2**exp for exp in range(15,29)]
onorm_list = []
fnorm_list = []

for i, dist in enumerate(d_list):

    spectrum = torch.load(path + f"CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}_P{p}.pt")
    svals = spectrum['S']
    svals_sorted, indices_sorted = torch.sort(svals, descending=True)
    onorm_list.append(svals_sorted[0])
    fnorm_list.append((svals_sorted**2).sum()**.5)
    print(dist, svals_sorted[0], (svals_sorted**2).sum()**.5)
    ax[0].plot( 1+torch.arange(svals.size(0)), svals_sorted, f'C{i}', label=fr'$t={dist}$')
#     ax[1].plot( 1+torch.arange(svals.size(0)), svals_sorted*p**.5, f'C{i}', label=fr'$P=2^{{exponent}}$')

i += 1
max_dist = 2049
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE{vocab_size}.{split}_d{max_dist}"
dist = 2048
# d_list.append(dist)
spectrum = torch.load(path + f"CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}_P{p}.pt")
svals = spectrum['S']
svals_sorted, indices_sorted = torch.sort(svals, descending=True)
# onorm_list.append(svals_sorted[0])
# fnorm_list.append((svals_sorted**2).sum()**.5)
print(dist, svals_sorted[0], (svals_sorted**2).sum()**.5)
ax[0].plot( 1+torch.arange(svals.size(0)), svals_sorted, f'k--', label=fr'noise')

# gamma = 1.
# G = 1e-1
# ax[0].plot([1e1, 1e3], [G*1e1**(-gamma), G*1e3**(-gamma)], 'k--', label='$k^{-1}$')

ax[0].set_yscale('log')
ax[0].set_xscale('log')
ax[0].set_ylabel('singular values $\sigma_k$', fontsize=11)
ax[0].set_xlabel('rank $k$', fontsize=11)
ax[0].legend( fontsize=8, handlelength=1, loc='upper right')
ax[0].set_xlim(1,8192*8)
ax[0].set_ylim(1e-8,1e-1)

# ax[1].set_yscale('log')
# ax[1].set_xscale('log')
# ax[1].set_ylabel('$\sqrt{P}\sigma_k$', fontsize=11)
# ax[1].set_xlabel('rank $k$', fontsize=11)
# ax[1].set_xlim(1,8192)
# ax[1].set_ylim(1e-4,1e4)

ax[1].plot(d_list, onorm_list, f'C0', label='op. norm ($\sigma_1$)')
ax[1].plot(d_list, fnorm_list, f'C1', label='Fr. norm ($\mathrm{rms}(\sigma_i)$)')
fit_f = np.polyfit(np.log(np.array(d_list[:15])), np.log(np.array(fnorm_list[:15])), 1)
fit_o = np.polyfit(np.log(np.array(d_list[:15])), np.log(np.array(onorm_list[:15])), 1)
ax[1].plot(d_list, [math.exp(fit_o[1])*d**fit_o[0] for d in d_list], f'C0', linestyle='dashed')
ax[1].plot(d_list, [math.exp(fit_f[1])*d**fit_f[0] for d in d_list], f'C1', linestyle='dashed')
print('op norm fit:', fit_o)
print('F norm fit:', fit_f)
# ax[1].plot(p_list, [o*math.sqrt(vocab_size) for o in onorm_list], f'C2', label='scaled op. norm')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('distance $t$', fontsize=11)
ax[1].legend( fontsize=8, handlelength=1)

fig.tight_layout()
# Out:
# 1 tensor(0.0207) tensor(0.0312)
# 2 tensor(0.0133) tensor(0.0209)
# 3 tensor(0.0113) tensor(0.0155)
# 4 tensor(0.0076) tensor(0.0113)
# 6 tensor(0.0046) tensor(0.0073)
# 8 tensor(0.0025) tensor(0.0050)
# 12 tensor(0.0024) tensor(0.0034)
# 16 tensor(0.0010) tensor(0.0020)
# 24 tensor(0.0007) tensor(0.0014)
# 32 tensor(0.0006) tensor(0.0011)
# 48 tensor(0.0006) tensor(0.0010)
# 64 tensor(0.0005) tensor(0.0009)
# 96 tensor(0.0004) tensor(0.0007)
# 128 tensor(0.0004) tensor(0.0006)
# 192 tensor(0.0003) tensor(0.0004)
# 256 tensor(0.0002) tensor(0.0003)
# 512 tensor(5.2290e-05) tensor(8.1508e-05)
# 2048 tensor(1.9356e-05) tensor(6.1376e-05)
# op norm fit: [-0.88429318 -3.89501896]
# F norm fit: [-0.88341739 -3.42110388]

# %%
print(d_list, len(d_list))
end = 15
print(d_list[:end])


fit_f = np.polyfit(np.log(np.array(d_list[:end])), np.log(np.array(fnorm_list[:end])), 1)
fit_o = np.polyfit(np.log(np.array(d_list[:end])), np.log(np.array(onorm_list[:end])), 1)
print('op norm fit:', fit_o)
print('F norm fit:', fit_f)
# Out:
# [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 64, 96, 128, 192, 256, 512] 17
# [1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 64, 96, 128, 192]
# op norm fit: [-0.88429318 -3.89501896]
# F norm fit: [-0.88341739 -3.42110388]

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.2), dpi=120)
# fig, ax = plt.subplots(1, 2, figsize=(2*5.7, 1*3.6), dpi=120)

base = matplotlib.colormaps["plasma"]                  # purple -> yellow
cmap  = matplotlib.colors.LinearSegmentedColormap.from_list(
    "plasma_trunc", base(np.linspace(0.05, 0.9, 256))
)
u = np.linspace(0, 1, 6)              # [0, 1]
colors2 = cmap(u)                     # shape (4,4) RGBA

ax.plot(d_list, onorm_list, color=colors2[0], marker='.', label=r'$\| C(n) \|_{\mathrm{op}}$')
ax.plot(d_list, fnorm_list, color=colors2[4], marker='.', label=r'$\| C(n) \|_{\mathrm{F}}$')
ax.plot(d_list, [math.exp(fit_o[1])*d**fit_o[0] for d in d_list], 'k--',label=r'$x^{-\beta}$, $\beta=$'+'{:03.2f}'.format(-fit_o[0]))

ax.legend(fontsize=8, handlelength=1)
ax.set_xscale('log')
ax.set_yscale('log')

# ax.set_ylabel(r'AR loss $\mathcal{L}(P)$', fontsize=10)
ax.set_xlabel(r'token separation $n$', fontsize=10)

# ticks  = [1, 2, 3, 4]
# labels = ["1", "2", "3", "4"]  # must match length/order
# ax.set_yticks(ticks)
# ax.set_yticklabels(labels)


fig.tight_layout()

# %%
fig.savefig(f'tinystories/'+f'C_n__tinystories.BPE8192.pdf',  bbox_inches="tight")

# %% [markdown]
# ## Size vs P (operator norm)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
fig, ax = plt.subplots(1, 1, figsize=(1.5*3.8, 1.5*2.4), dpi=120)


ax.plot(d_list, onorm_list, f'k', label='op. norm ($\sigma_1$)')
top_noise = onorm_list[-1]*(2**28)**.5
min_o = onorm_list[-1]
max_o = onorm_list[0]
print(top_noise)
for i, p in enumerate([2**18, 2**19, 2**20, 2**21, 2**22, 2**23, 2**24]):
    ax.plot(d_list, [top_noise/(p**.5) for _ in d_list], f'C{i}', linestyle='dashed', label=f'P={p}')
    resolved = [o for o in onorm_list if o > top_noise/(p**.5)]
    t_res = d_list[len(resolved)-1]
    print(p, t_res)
    ax.plot([t_res, t_res], [min_o, max_o], f'C{i}', linestyle='dashed')
#     print(fr'$P={p}, t(P)=$', max_dist)
# ax.plot(d_list, fnorm_list, f'C1', label='Fr. norm ($\mathrm{rms}(\sigma_i)$)')
# gamma = 1.
# G = 1e-1
# ax[0].plot([1e1, 1e3], [G*1e1**(-gamma), G*1e3**(-gamma)], 'k--', label='$k^{-1}$')

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylabel('operator norm', fontsize=11)
ax.set_xlabel('distance $t$', fontsize=11)
ax.legend( fontsize=8, handlelength=1, loc='upper right')
# ax[0].set_xlim(1,8192*8)
# ax[0].set_ylim(1e-8,1e-1)
# Out:
# tensor(0.8567)
# 262144 12
# 524288 12
# 1048576 16
# 2097152 32
# 4194304 64
# 8388608 128
# 16777216 128

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
fig, ax = plt.subplots(1, 2, figsize=(3*3.8, 1.5*2.4), dpi=120)

vocab_size = 8192
split = 'train'
max_dist = 1025
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE{vocab_size}.{split}_d{max_dist}"

# unigram = torch.load("tinystories/"+f"unigram_tinystories.BPE8192.{split}.pt")
# unigram_cov = torch.diag(unigram)-unigram[:,None] @ unigram[None]
# svals = torch.linalg.svdvals(unigram_cov)
# svals_sorted, _ = torch.sort(svals, descending=True)
# ax[0].plot( 1+torch.arange(svals_sorted.size(0)), svals_sorted, f'k--', label=fr'$t={0}$')

p = 2**28
d_list = [1,2,3,4,6,8,12,16]
# dist = 2048
# p_list = [ 2**exp for exp in range(15,29)]
onorm_list = []
fnorm_list = []

for i, dist in enumerate(d_list):

    spectrum = torch.load(path + f"CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}_P{p}.pt")
    svals = spectrum['S']
    svals_sorted, indices_sorted = torch.sort(svals, descending=True)
    onorm_list.append(svals_sorted[0])
    fnorm_list.append((svals_sorted**2).sum()**.5)
    print(dist, svals_sorted[0], (svals_sorted**2).sum()**.5)
    ax[0].plot( 1+torch.arange(svals.size(0)), svals_sorted, f'C{i}', label=fr'$t={dist}$')
#     ax[1].plot( 1+torch.arange(svals.size(0)), svals_sorted*p**.5, f'C{i}', label=fr'$P=2^{{exponent}}$')

i += 1
max_dist = 2049
path = "tinystories/correlations/"
prefix = f"correlations_tinystories.BPE{vocab_size}.{split}_d{max_dist}"
dist = 2048
d_list.append(dist)
spectrum = torch.load(path + f"CovSVD_tinystories.BPE8192.train_d{max_dist}_t{dist}_P{p}.pt")
svals = spectrum['S']
svals_sorted, indices_sorted = torch.sort(svals, descending=True)
onorm_list.append(svals_sorted[0])
fnorm_list.append((svals_sorted**2).sum()**.5)
print(dist, svals_sorted[0], (svals_sorted**2).sum()**.5)
ax[0].plot( 1+torch.arange(svals.size(0)), svals_sorted, f'C{i}', label=fr'$t={dist}$')

# gamma = 1.
# G = 1e-1
# ax[0].plot([1e1, 1e3], [G*1e1**(-gamma), G*1e3**(-gamma)], 'k--', label='$k^{-1}$')

ax[0].set_yscale('log')
ax[0].set_xscale('log')
ax[0].set_ylabel('singular values $\sigma_k$', fontsize=11)
ax[0].set_xlabel('rank $k$', fontsize=11)
ax[0].legend( fontsize=8, handlelength=1, loc='upper right')
ax[0].set_xlim(1,8192*8)
ax[0].set_ylim(1e-8,1e-1)

# ax[1].set_yscale('log')
# ax[1].set_xscale('log')
# ax[1].set_ylabel('$\sqrt{P}\sigma_k$', fontsize=11)
# ax[1].set_xlabel('rank $k$', fontsize=11)
# ax[1].set_xlim(1,8192)
# ax[1].set_ylim(1e-4,1e4)

ax[1].plot(d_list, onorm_list, f'C0', label='op. norm ($\sigma_1$)')
ax[1].plot(d_list, fnorm_list, f'C1', label='Fr. norm ($\mathrm{rms}(\sigma_i)$)')
fit_f = np.polyfit(np.log(np.array(d_list[:7])), np.log(np.array(fnorm_list[:7])), 1)
fit_o = np.polyfit(np.log(np.array(d_list[:7])), np.log(np.array(onorm_list[:7])), 1)
ax[1].plot(d_list, [math.exp(fit_o[1])*d**fit_o[0] for d in d_list], f'C0', linestyle='dashed')
ax[1].plot(d_list, [math.exp(fit_f[1])*d**fit_f[0] for d in d_list], f'C1', linestyle='dashed')
print('op norm fit:', fit_o)
print('F norm fit:', fit_f)
# ax[1].plot(p_list, [o*math.sqrt(vocab_size) for o in onorm_list], f'C2', label='scaled op. norm')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('distance $t$', fontsize=11)
ax[1].legend( fontsize=8, handlelength=1)
# Out:
# 1 tensor(0.0207) tensor(0.0312)
# 2 tensor(0.0133) tensor(0.0209)
# 3 tensor(0.0113) tensor(0.0155)
# 4 tensor(0.0076) tensor(0.0113)
# 6 tensor(0.0046) tensor(0.0073)
# 8 tensor(0.0025) tensor(0.0050)
# 12 tensor(0.0024) tensor(0.0034)
# 16 tensor(0.0010) tensor(0.0020)
# 2048 tensor(1.9356e-05) tensor(6.1376e-05)
# op norm fit: [-0.95191086 -3.69614336]
# F norm fit: [-0.92615342 -3.29455113]

# %%
top_noise = onorm_list[-1]*(2**28)**.5
print('noise norm factor:', top_noise.item())

print(onorm_list)

T = 16

for i, o in enumerate(onorm_list):
    t = d_list[i]
    P = (top_noise/o)**2
    P_corr = P/(1.-(t-1)/T)
    print(fr'distance {t}, num. data {P} ({P_corr} if corrected by $1-t/T$)')
# Out:
# noise norm factor: 0.3171302080154419
# [tensor(0.0207), tensor(0.0133), tensor(0.0113), tensor(0.0076), tensor(0.0046), tensor(0.0025), tensor(0.0024), tensor(0.0010), tensor(1.9356e-05)]
# distance 1, num. data 235.7955780029297 (235.7955780029297 if corrected by $1-t/T$)
# distance 2, num. data 565.9888916015625 (603.7214965820312 if corrected by $1-t/T$)
# distance 3, num. data 789.2413330078125 (901.9901123046875 if corrected by $1-t/T$)
# distance 4, num. data 1752.7052001953125 (2157.175537109375 if corrected by $1-t/T$)
# distance 6, num. data 4833.0234375 (7029.85205078125 if corrected by $1-t/T$)
# distance 8, num. data 15730.1181640625 (27964.654296875 if corrected by $1-t/T$)
# distance 12, num. data 16832.4453125 (53863.82421875 if corrected by $1-t/T$)
# distance 16, num. data 93886.734375 (1502187.75 if corrected by $1-t/T$)
# distance 2048, num. data 268435456.0 (-2114705.75 if corrected by $1-t/T$)

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 1, figsize=(2*3.8, 1.5*2.4), dpi=120)

for i, p in enumerate([2**exp for exp in range(8, 29)]):

    if p<32768:
        x_pts = [1, 2, 3, 4, 6, 8, 12, 16, 24]
    else:
        x_pts = [ 1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 64, 96, 128, 192, 256, 384, 512, 1024]
    y_pts = []

    for x in x_pts:
        results = torch.load(path+prefix+f"_t{x}_P{p}.pt")
        y_pts.append(results['corr'])

    ax.plot(x_pts, y_pts, f'C{i}', label=fr'$P={p}$')
    ax.plot(x_pts, [p**(-.5)/(vocab_size) for x in x_pts], f'C{i}', linestyle='dashed')

ax.set_xlim(1e0,1e4)
ax.set_xscale('log')
ax.set_xlabel(r'token distance $t$', fontsize=11)
ax.set_yscale('log')
ax.set_ylabel(r'correlation $\hat{C}_P(t)$', fontsize=11)
ax.legend( fontsize=8, handlelength=1)

fig.tight_layout()

# %%
fig.savefig(path+f'corr-vs-t_tinystories.BPE8192.train_d1025.pdf')

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 10,
    'lines.markersize': 4,
    'lines.linewidth': 1.0,
})
# fig, ax = plt.subplots(1, 1, figsize=(1*3.8, 1*2.4), dpi=120)
fig, ax = plt.subplots(1, 1, figsize=(1.5*3.8, 1.5*2.4), dpi=120)

for i, dist in enumerate([32, 64, 128, 256, 512, 1024]):


    x_pts = [2**exp for exp in range(15, 29)]
    y_pts = []

    for x in x_pts:
        results = torch.load(path+prefix+f"_t{dist}_P{x}.pt")
        y_pts.append(results['corr'].cpu())

    ax.plot(x_pts, y_pts, f'C{i}', label=fr'$t={dist}$')


ax.plot(x_pts, [x**(-.5)/(vocab_size) for x in x_pts], 'k--')

ax.set_xscale('log')
ax.set_xlabel(r'number of data $P$', fontsize=11)
ax.set_yscale('log')
ax.set_ylabel(r'correlation $\hat{C}_P(t)$', fontsize=11)
ax.legend( fontsize=8, handlelength=1)

fig.tight_layout()

# %%
fig.savefig(path+f'corr-vs-P_tinystories.BPE8192.train_d1025.pdf')
