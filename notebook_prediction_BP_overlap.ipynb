# %% [markdown]
# # Imports

# %%
from plot_ntp_overlaps_updated import plot_rhm_latent_probes

# %% [markdown]
# # Runs

# %%
results_dir = (
    "/mnt/beegfs/2a/mb12724/franc/small-language-modelling/"
    "collect_results/L4_latent_light_v2/"
)

fig, axs, info = plot_rhm_latent_probes(
    results_dir,
    metric="error",
    split="test",
    position="mean",
    xscale="log",
    yscale="linear",
)
